# %%
import matplotlib.pyplot as plt
import numpy
import pandas as pd

# %%
# %matplotlib inline

# %%
base_df = pd.read_csv("./cards.csv")
# Out:
# C:\Users\Damien\AppData\Local\Temp\ipykernel_1212\3865153005.py:1: DtypeWarning: Columns (3,11,18,22,26,29,53,59,60,67,68,77,78,85,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   base_df = pd.read_csv("./cards.csv")

# %%
print(base_df["name"].unique().size)
# Out:
# 26712

# %% [markdown]
# ## Who are the most productive artists ?

# %%
df = base_df[["artist", "name"]].dropna()

# separate solo and duo, by applying a mask
df["mask"] = df["artist"].str.contains("&")  # & present if duo
df = df[["artist", "name", "mask"]].dropna().drop_duplicates()

df_solo = df[~df["mask"]].value_counts("artist", ascending=True)[-10:]
df_duo = df[df["mask"]].value_counts("artist", ascending=True)[-10:]

fig, axes = plt.subplots(nrows=2)
fig.set_size_inches(10, 7.5)

solo_plot = df_solo.plot(kind="barh", ax=axes[0], rot=0, edgecolor="k")
solo_plot.tick_params("x", which="both", bottom=False, labelbottom=False)
solo_plot.bar_label(solo_plot.containers[0], padding=2)
solo_plot.set_title("Solo artist")
solo_plot.set_ylabel("")

duo_plot = df_duo.plot(kind="barh", ax=axes[1], rot=0, edgecolor="k")
duo_plot.tick_params("x", which="both", bottom=False, labelbottom=False)
duo_plot.bar_label(duo_plot.containers[0], padding=2)
solo_plot.set_title("Duo of artists")
duo_plot.set_ylabel("")

plt.show()

# %% [markdown]
# ## What are the most reprinted cards ?

# %%
# using the "printings" column we get slightly smaller results.
# probably because "printings" only tracks in which set the cards are present without tracking how many time

df = base_df[["name", "types"]]

df = df.loc[(df["types"] != "Land")]  # exclude the lands
df = df["name"].value_counts(ascending=True)[-10:]  # select the top ten

plot = df.plot(kind="barh", rot=0, edgecolor="k")
plot.bar_label(plot.containers[0], padding=2)
plot.tick_params("x", which="both", bottom=False, labelbottom=False)
plot.set_title("Most reprinted cards (excluding lands)")
plot.set_xlabel("")
plot.set_ylabel("")

plt.show()

# %% [markdown]
# ## What is the proportion of original cards, among all printed cards ?

# %%
df = base_df[["name", "isReprint"]]

df = df.drop_duplicates().dropna()
df = df.value_counts("isReprint").rename({0: "Reprint", 1: "Original"})

plot = df.plot(
    kind="pie",
    autopct="%.1f",
    wedgeprops={"edgecolor": "k", "linewidth": 2},
    startangle=90,
)
plot.set_ylabel("")

plt.show()
