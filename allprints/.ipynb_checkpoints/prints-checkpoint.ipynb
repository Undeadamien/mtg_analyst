# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 50)

# %%
default_df = pd.read_csv("./cards.csv", low_memory=False)

# %%
default_df.head()

# Check basic statistics of the data
default_df.describe()

# Check data types of columns and missing values
default_df.info()
# Out:
#               index            id  attractionLights  cardKingdomEtchedId
# count  80995.000000  80995.000000               0.0           878.000000  \
# mean   40497.000000  40498.000000               NaN        255955.255125
# std    23381.386864  23381.386864               NaN         12109.536244
# min        0.000000      1.000000               NaN        238711.000000
# 25%    20248.500000  20249.500000               NaN        244394.250000
# 50%    40497.000000  40498.000000               NaN        257224.500000
# 75%    60745.500000  60746.500000               NaN        263163.250000
# max    80994.000000  80995.000000               NaN        277322.000000
#
#        cardKingdomFoilId  cardKingdomId   cardsphereId  convertedManaCost
# count       40708.000000   59924.000000   63759.000000       80995.000000  \
# mean       197212.584553  185463.656048   50083.431594          27.687407
# std         64981.001551   78501.340685   29548.552572        4969.148158
# min         39000.000000   10000.000000       2.000000           0.000000
# 25%        132427.750000  125764.750000   23897.000000           2.000000
# 50%        215610.500000  213144.500000   49869.000000           3.000000
# 75%        246870.250000  243868.250000   75172.000000           4.000000
# max        277666.000000  277665.000000  102914.000000     1000000.000000
#
#          defense    edhrecRank  edhrecSaltiness  faceConvertedManaCost
# count  52.000000  74374.000000     57974.000000            2314.000000  \
# mean    4.634615   9653.775352         0.273449               2.081677
# std     1.010316   7395.535634         0.297565               1.884651
# min     3.000000      1.000000         0.010000               0.000000
# 25%     4.000000   2908.000000         0.090000               0.000000
# 50%     4.000000   8356.500000         0.190000               2.000000
# 75%     5.000000  15701.000000         0.320000               3.000000
# max     7.000000  24939.000000         2.920000              10.000000
#
#        faceManaValue        hand  hasAlternativeDeckLimit  hasContentWarning
# count    2314.000000  119.000000             80995.000000       80995.000000  \
# mean        2.081677    0.084034                 0.000407           0.000358
# std         1.884651    1.211385                 0.020181           0.018919
# min         0.000000   -4.000000                 0.000000           0.000000
# 25%         0.000000   -1.000000                 0.000000           0.000000
# 50%         2.000000    0.000000                 0.000000           0.000000
# 75%         3.000000    1.000000                 0.000000           0.000000
# max        10.000000    3.000000                 1.000000           1.000000
#
#             hasFoil    hasNonFoil  isAlternative     isFullArt       isFunny
# count  80995.000000  80995.000000   80995.000000  80995.000000  80995.000000  \
# mean       0.587234      0.878906       0.051324      0.017495      0.016371
# std        0.492335      0.326238       0.220659      0.131107      0.126900
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%        0.000000      1.000000       0.000000      0.000000      0.000000
# 50%        1.000000      1.000000       0.000000      0.000000      0.000000
# 75%        1.000000      1.000000       0.000000      0.000000      0.000000
# max        1.000000      1.000000       1.000000      1.000000      1.000000
#
#        isOnlineOnly   isOversized       isPromo  isRebalanced     isReprint
# count  80995.000000  80995.000000  80995.000000  80995.000000  80995.000000  \
# mean       0.102834      0.007025      0.118118      0.002469      0.607383
# std        0.303743      0.083522      0.322750      0.049631      0.488336
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      1.000000
# 75%        0.000000      0.000000      0.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          isReserved     isStarter  isStorySpotlight    isTextless
# count  80995.000000  80995.000000      80995.000000  80995.000000  \
# mean       0.018149      0.311377          0.003259      0.001580
# std        0.133492      0.463060          0.056999      0.039722
# min        0.000000      0.000000          0.000000      0.000000
# 25%        0.000000      0.000000          0.000000      0.000000
# 50%        0.000000      0.000000          0.000000      0.000000
# 75%        0.000000      1.000000          0.000000      0.000000
# max        1.000000      1.000000          1.000000      1.000000
#
#        isTimeshifted        life       manaValue          mcmId
# count   80995.000000  119.000000    80995.000000   68495.000000  \
# mean        0.002729    1.084034       27.687407  312968.103175
# std         0.052165    5.683130     4969.148158  240515.980872
# min         0.000000   -8.000000        0.000000       1.000000
# 25%         0.000000   -3.000000        2.000000   17764.500000
# 50%         0.000000    0.000000        3.000000  293789.000000
# 75%         0.000000    4.000000        4.000000  532404.500000
# max         1.000000   30.000000  1000000.000000  710911.000000
#
#            mcmMetaId    mtgArenaId     mtgoFoilId         mtgoId
# count   51224.000000  11520.000000   24749.000000   42004.000000  \
# mean   134211.409222  75347.466059   37901.958180   56790.711218
# std    145331.341623   7306.453407   19198.301743   29621.864031
# min         1.000000   6993.000000     303.000000       9.000000
# 25%      4844.750000  70447.750000   21670.000000   30890.500000
# 50%     10786.000000  75616.500000   36817.000000   55748.000000
# 75%    227025.250000  80275.250000   53112.000000   82696.500000
# max    419602.000000  87130.000000  451148.000000  110466.000000
#
#         multiverseId  tcgplayerEtchedProductId  tcgplayerProductId
# count   55477.000000                889.000000        70459.000000
# mean   332727.553220             291658.349831       158725.951802
# std    207087.761199              89405.864565       133718.047136
# min         1.000000             221417.000000           86.000000
# 25%    130513.000000             235642.000000        36423.500000
# 50%    407522.000000             264148.000000       145371.000000
# 75%    502728.000000             277230.000000       236304.500000
# max    615973.000000             496066.000000       497033.000000

# %% [markdown]
# ## Who are the most productive artists ?
#
# Using the "artist" column, I managed to count the number of card illustrated by each artist.
# Some cards are illustrated by two artists, and to avoid confusion I prefered to plot them separately.
# Cards that have multiple artwork such as double-faced cards are represented only once.
# Artists may appear in multiple duos.
#
# We can see that the most prolific artist is **Kev Walker** with around **450** card, almost half as much as the second artist.
# We can also see that the most prolific duo of artist is **Zoltan Boros & Gabor Szikszai** with around **130** card.

# %%
df = default_df[["name", "artist"]].dropna().drop_duplicates()

df_solo = df[~df["artist"].str.contains("&")].value_counts("artist", ascending=False)
df_duo = df[df["artist"].str.contains("&")].value_counts("artist", ascending=False)

fig, axes = plt.subplots(ncols=2, figsize=(15, 2.5))

for axe in axes:
    for side in ["top", "right"]:
        axe.spines[f"{side}"].set_visible(False)

solo_plot = df_solo.plot(
    ax=axes[0],
    color="dodgerblue",
    kind="area",
    legend=False,
    rot=0,
    title="Cards by artist",
    xlabel=f"{df_solo.shape[0]} artist",
)
solo_plot.set_xlim(left=0)
solo_plot.tick_params("x", which="both", bottom=False, labelbottom=False)

duo_plot = df_duo.plot(
    ax=axes[1],
    color="dodgerblue",
    kind="area",
    legend=False,
    rot=0,
    title="Cards by duo of artist",
    xlabel=f"{df_duo.shape[0]} duo of artist",
)
duo_plot.set_xlim(left=0)
duo_plot.tick_params("x", which="both", bottom=False, labelbottom=False)

None  # avoid useless output

# %%
TOP = 10

df = default_df[["name", "artist"]].dropna().drop_duplicates()

df_solo = df[~df["artist"].str.contains("&")].value_counts("artist", ascending=True)
df_duo = df[df["artist"].str.contains("&")].value_counts("artist", ascending=True)

df_solo = df_solo[-TOP:]
df_duo = df_duo[-TOP:]

fig, axes = plt.subplots(nrows=2, figsize=(15, 7.5))
for axe in axes:
    for side in ["top", "bottom", "right", "left"]:
        axe.spines[f"{side}"].set_visible(False)

solo_plot = df_solo.plot(
    ax=axes[0],
    color=["dodgerblue" if x == 0 else "lightgrey" for x in range(TOP)][::-1],
    edgecolor="k",
    kind="barh",
    rot=0,
    title="Cards by artist",
    width=1,
    ylabel="",
)
solo_plot.tick_params("x", which="both", bottom=False, labelbottom=False)
solo_plot.bar_label(solo_plot.containers[0], padding=2)

duo_plot = df_duo.plot(
    ax=axes[1],
    color=["dodgerblue" if x == 0 else "lightgrey" for x in range(TOP)][::-1],
    edgecolor="black",
    kind="barh",
    rot=0,
    title="Cards by duo of artist",
    width=1,
    ylabel="",
)
duo_plot.tick_params("x", which="both", bottom=False, labelbottom=False)
duo_plot.bar_label(duo_plot.containers[0], padding=2)

None  # avoid useless output

# %% [markdown]
# ## What are the 10 most reprinted cards ?
#
# Using the "name" column, I counted how many times each card appears in the dataframe, which gives us the number of unique print.
# Using the "scryfallIllustrationId" column, I also got the number of unique illustrations each card has among its printed version.
# I preferred to exclude the lands because they will obviously be on top, since the basic lands are printed in each main set and several times per set.
#
# We can see that the most reprinted card is **Sol Ring**, its first version was released on **1993-08-05** in the set **Limited Edition Alpha**.
# We can also be seen that most of the reprints use an existing illustration.
#
# Strangely enough I thought **Black Lotus** would appear in the most reprinted cards, due to its popularity, but after further inspection it appear that **Black Lotus** is in the Reserved List, is a list of card that will never be reprinted in order to preserve their value.
# The dataset has a column named "isReserved" referring to the Reserved list.

# %%
df = default_df
df = df.loc[(default_df["types"] != "Land")]  # exclude all lands
df = df[["name", "types", "scryfallIllustrationId"]]

# assemble the data to plot
temp_df = pd.DataFrame()
temp_df["Reprint"] = df["name"].value_counts()
cols = ["name", "scryfallIllustrationId"]
temp_df["Artwork"] = df[cols].drop_duplicates().groupby("name").count()
df = temp_df[:10]

fig, axes = plt.subplots(figsize=(17, 5))
for side in ["top", "right", "left"]:  # remove the plot borders
    axes.spines[f"{side}"].set_visible(False)

plot = df.plot(
    kind="bar",
    ax=axes,
    title="The 10 most reprinted cards",
    xlabel="",
    ylabel="",
    rot=0,
    edgecolor="black",
    color={"Artwork": "dodgerblue", "Reprint": "lightgrey"},
)
plot.tick_params("y", which="both", left=False, labelleft=False)
plot.bar_label(plot.containers[0], padding=2)
plot.bar_label(plot.containers[1], padding=2)

None

# %% [markdown]
# ## What is the proportion of original concept ?
#
# Using the "isReprint" column, I highlighted the proportion of card being a reprint of another card.
#
# We can see that only 1/3 of the entries in the dataset represent an original card.

# %%
df = default_df

original = default_df[default_df["isReprint"] == 0].shape[0]
reprint = default_df[default_df["isReprint"] == 1].shape[0]

# assemble the number of reprint and original print
df = pd.Series(data={f"Original: {original}": original, f"Reprint: {reprint}": reprint})

plot = df.plot.pie(
    startangle=0,
    title="Proportion of reprint",
    colors=["dodgerblue", "lightgrey"],
    wedgeprops={"edgecolor": "black", "linewidth": 1.5, "antialiased": True},
)

None

# %% [markdown]
# ## What are the most used keyword abilities?
#
# Using the "keywords" column, I managed to count the number of times each keyword appears.
# We can see that the most common keyword ability among all printed card is **Flying**
#
# _I will try to regroup the values, ​​by the color of the card on which the keyword appears_

# %%
df = default_df.drop_duplicates(["name", "side"])

# parse the keywords columns and retrieve the most used abilities
df = (
    df["keywords"]
    .dropna()
    .str.split(",", expand=True)
    .stack(dropna=True)
    .value_counts()[:10]
)

fig, axes = plt.subplots(figsize=(10, 5))
for side in ["top", "right"]:  # remove some plot borders
    axes.spines[f"{side}"].set_visible(False)

plot = df.plot(
    kind="bar",
    ax=axes,
    title="Most used keyword abilities",
    xlabel="",
    ylabel="",
    rot=0,
    width=0.75,
    edgecolor="black",
    color=["dodgerblue" if x == 0 else "lightgrey" for x in range(10)],
)

None
